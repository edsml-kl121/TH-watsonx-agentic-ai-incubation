# %%
import requests

# Base URL of your FastAPI server
url = "http://127.0.0.1:8000/researchsuppliers/"
# url = "https://research-supplier.1u1bpgsnsvuw.us-south.codeengine.appdomain.cloud/researchsuppliers"

# user_query = "ค้นหาผู้จัดจำหน่ายผลิตภัณฑ์ Xtralife"
# user_query = "Supplier Excelentia Supplies และ Global Office มีข้อดีและข้อเสียยังไงบ้าง"
# user_query = "ช่วย Research ผู้จัดจำหน่ายสินค้า Xtralife."
# user_query = "ช่วยค้นคว้าเกี่ยวกับผู้จัดจำหน่าย Xtralife ให้คะแนนซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด พร้อมทั้งแบ่งปันเหตุผลด้วย ข้อมูลราคาสำหรับซัพพลายเออร์ ทั้งหมด 3 เจ้า มีดังนี้: [{'Unit Price': 61.5, 'Pricebook Name': 'Excelentia Supplies'}, {'Unit Price': 76.9, 'Pricebook Name': 'Global Office Solutions'}, {'Unit Price': 92.3, 'Pricebook Name': 'CGV Supplier'}] พิจารณาข้อกำหนดและบทวิจารณ์การขายของซัพพลายเออร์เหล่านี้ด้วย"
# Research for Product Xtralife Supplier
# Sample query string
user_query ="ค้นหาผู้จัดจำหน่ายของสินค้า Xtralife ที่ดีที่สุด"
params = {
    "query": user_query
}

# Send GET request
response = requests.get(url, params=params)

# Check response status and print result
if response.status_code == 200:
    print("✅ Success")
    print("Response:")
    print(response.json())
else:
    print("❌ Failed with status code:", response.status_code)
    print("Response:", response.text)

# %%
print(response.json()["Agent Response"])
# Out:
# ### การจัดอันดับซัพพลายเออร์ของสินค้า Xtralife
# เราจะพิจารณาจากต้นทุนและคุณภาพของการบริการในการจัดอันดับซัพพลายเออร์ โดยพิจารณาจากข้อมูลที่ให้มาและข้อกำหนดอื่นๆ ที่อาจมีผลต่อการขาย
#
# #### 1. **Excelentia Supplies**
# - **ราคาต่อหน่วย:** 61.5
# - **คะแนน:** 9/10
# - **เหตุผล:** มีราคาต่ำที่สุดในบรรดาซัพพลายเออร์ทั้งหมด ซึ่งสามารถช่วยลดต้นทุนการผลิตและเพิ่มความสามารถในการแข่งขันในตลาด นอกจากนี้ยังอาจมีบทวิจารณ์ที่ดีเกี่ยวกับการบริการและคุณภาพสินค้า
#
# #### 2. **Global Office Solutions**
# - **ราคาต่อหน่วย:** 76.9
# - **คะแนน:** 7/10
# - **เหตุผล:** มีราคาสูงกว่า Excelentia Supplies แต่ยังคงถือว่าเป็นตัวเลือกที่ดีหากพิจารณาจากคุณภาพของสินค้าและบริการที่มีมาตรฐาน แม้ว่าจะไม่ใช่ตัวเลือกที่ประหยัดที่สุด แต่ก็อาจมีประโยชน์จากบริการหลังการขายหรือการรับประกันที่ดี
#
# #### 3. **CGV Supplier**
# - **ราคาต่อหน่วย:** 92.3
# - **คะแนน:** 5/10
# - **เหตุผล:** มีราคาสูงสุดในบรรดาซัพพลายเออร์ทั้งหมด ซึ่งอาจทำให้ไม่สามารถแข่งขันในตลาดได้ดีนัก เว้นแต่จะมีคุณภาพหรือบริการที่เหนือกว่าอย่างมาก ซึ่งอาจไม่คุ้มค่ากับราคาที่สูง
#
# ### สรุป
# การวิเคราะห์ข้อมูลและพิจารณาจากต้นทุนและคุณภาพของการบริการ **Excelentia Supplies** เป็นตัวเลือกที่ดีที่สุดสำหรับการจัดหาสินค้า Xtralife เนื่องจากราคาที่ต่ำและอาจมีคุณภาพการบริการที่ดี ตัวเลือกอื่นๆ เช่น **Global Office Solutions** และ **CGV Supplier** อาจเป็นทางเลือกที่ดีหากมีข้อกำหนดหรือบริการพิเศษที่ไม่ได้กล่าวถึงในข้อมูลที่ให้มา

# %%
full_question = f"""ช่วยค้นคว้าเกี่ยวกับผู้จัดจำหน่าย Xtralife ให้คะแนนซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด พร้อมทั้งแบ่งปันเหตุผลด้วย ข้อมูลราคาสำหรับซัพพลายเออร์ ทั้งหมด 3 เจ้า มีดังนี้: [{'Unit Price': 61.5, 'Pricebook Name': 'Excelentia Supplies'}, {'Unit Price': 76.9, 'Pricebook Name': 'Global Office Solutions'}, {'Unit Price': 92.3, 'Pricebook Name': 'CGV Supplier'}] พิจารณาข้อกำหนดและบทวิจารณ์การขายของซัพพลายเออร์เหล่านี้ด้วย"""

# %%
[{'Unit Price': 61.5, 'Pricebook Name': 'Excelentia Supplies'}, {'Unit Price': 76.9, 'Pricebook Name': 'Global Office Solutions'}, {'Unit Price': 92.3, 'Pricebook Name': 'CGV Supplier'}]
