# %%
import requests

# URL of your running FastAPI server
# url = "http://127.0.0.1:8000/calculate-reorder-quantity"
url = "https://calculate-reorder-quantity.1u1bpgsnsvuw.us-south.codeengine.appdomain.cloud/calculate-reorder-quantity"

# Payload to send
# payload = {
#     "current_inventory": 50,
#     "historic_data": 120,
#     "forecast": 100
# }
payload = {
    "current_inventory": 1000,
    "historic_data": 3400,
    "forecast": 3107
}

# Make the POST request
response = requests.post(url, json=payload)

# Print the response
if response.status_code == 200:
    print("Reorder Quantity:", response.json()["reorder_quantity"])
    print("Reasoning:", response.json()["reasoning"])
else:
    print("Request failed with status code:", response.status_code)
    print(response.text)
# Out:
# Reorder Quantity: 2447
# Reasoning: การคำนวณปริมาณการสั่งซื้อใหม่ซึ่งเหมาะสมที่สุดได้ดำเนินไปตามขั้นตอนดังนี้ ขั้นแรก เราได้คำนวณ Shortfall ซึ่งเท่ากับ Forecast ลบด้วย Inventory ในกรณีนี้ Shortfall = 3107 - 1000 = 2107 จากนั้น เนื่องจากระยะ Shortfall นี้มากกว่าปริมาณการขายในเดือก่อน (3400) จริงๆ แล้วShortfall น้อยกว่า แต่ถ้าเราดำเนินการตามเงื่อนไขที่กำหนด ซึ่ง จะต้องมีการคำนวณ Safety Stock 10% ของปริมาณการขายในเดือก่อน ซึ่งเท่ากับ 340 เนื่องจาก Shortfall น้อยกว่าhistoric sales จริงๆ แล้วเราคำนวณ safety stock แล้วบวกเข้ากับ shortfall ทำให้ได้ปริมาณการสั่งซื้อใหม่ (Reorder Quantity) เป็น 2447 โดยรวมแล้ว การเลือกปริมาณการสั่งซื้อใหม่ 2447 หน่วยนี้มีเหตุผลมาจากการที่เราต้องการมีระยะการกัน kapsamında เพื่อให้พร้อมรับมือกับความต้องการที่อาจเกิดขึ้นในอนาคต และลดโอกาสที่จะเกิดปัญหาการขาดสินค้าในระหว่างรอการเข้าของสินค้าใหม่ พร้อมทั้งยังช่วยให้เราไม่มีการเก็บสินค้าเกินจำเป็น ซึ่งจะช่วยลดต้นทุนการเก็บสินค้าและเพิ่มประสิทธิภาพในกระบวนการขาย

# %%
import requests

# Base URL of your FastAPI server
# url = "http://127.0.0.1:8000/researchsuppliers/"
url = "https://research-supplier.1u1bpgsnsvuw.us-south.codeengine.appdomain.cloud/researchsuppliers"

# user_query = "ค้นหาผู้จัดจำหน่ายผลิตภัณฑ์ Xtralife"
# user_query = "Supplier Excelentia Supplies และ Global Office มีข้อดีและข้อเสียยังไงบ้าง"
# user_query = "ช่วย Research ผู้จัดจำหน่ายสินค้า Xtralife."
user_query = "ช่วยค้นคว้าเกี่ยวกับผู้จัดจำหน่าย Xtralife ให้คะแนนซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด พร้อมทั้งแบ่งปันเหตุผลด้วย ข้อมูลราคาสำหรับซัพพลายเออร์ ทั้งหมด 3 เจ้า มีดังนี้: [{'Unit Price': 61.5, 'Pricebook Name': 'Excelentia Supplies'}, {'Unit Price': 76.9, 'Pricebook Name': 'Global Office Solutions'}, {'Unit Price': 92.3, 'Pricebook Name': 'CGV Supplier'}] พิจารณาข้อกำหนดและบทวิจารณ์การขายของซัพพลายเออร์เหล่านี้ด้วย"
# Research for Product Xtralife Supplier
# Sample query string
params = {
    "query": user_query
}

# Send GET request
response = requests.get(url, params=params)

# Check response status and print result
if response.status_code == 200:
    print("✅ Success")
    print("Response:")
    print(response.json())
else:
    print("❌ Failed with status code:", response.status_code)
    print("Response:", response.text)

print(response.json()["Agent Response"])
# Out:
# ✅ Success
# Response:
# {'Agent Response': 'การวิเคราะห์ซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด โดยพิจารณาจากข้อมูลราคาสำหรับซัพพลายเออร์ทั้งหมด 3 เจ้า ได้แก่ Excelentia Supplies, Global Office Solutions และ CGV Supplier\n\n1. **Excelentia Supplies** - มีราคา Unit Price ต่ำสุดอยู่ที่ 61.5 ดอลลาร์ มีอัตราการจัดส่งตรงเวลา 95% และอัตราการคืนสินค้า 2% ซึ่งเป็นตัวเลือกที่ดีที่สุด\n2. **Global Office Solutions** - มีราคา Unit Price อยู่ที่ 76.9 ดอลลาร์ มีอัตราการจัดส่งตรงเวลา 92% และอัตราการคืนสินค้า 1% เป็นตัวเลือกที่สอง\n3. **CGV Supplier** - มีราคา Unit Price สูงสุดอยู่ที่ 92.3 ดอลลาร์ ไม่มีข้อมูลเกี่ยวกับอัตราการจัดส่งตรงเวลาและอัตราการคืนสินค้า จึงเป็นตัวเลือกที่แย่ที่สุด\n\nโดยรวมแล้ว Excelentia Supplies เป็นตัวเลือกที่ดีที่สุดสำหรับการจัดซื้อจัดจ้าง เนื่องจากราคาถูกที่สุดและมีอัตราการจัดส่งตรงเวลาที่ดี และมีอัตราการคืนสินค้าที่ไม่สูงเกินไป ในขณะที่ CGV Supplier เป็นตัวเลือกที่แย่ที่สุดเนื่องจากราคาสูงสุดและไม่มีข้อมูลเกี่ยวกับอัตราการจัดส่งตรงเวลาและอัตราการคืนสินค้า'}
# การวิเคราะห์ซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด โดยพิจารณาจากข้อมูลราคาสำหรับซัพพลายเออร์ทั้งหมด 3 เจ้า ได้แก่ Excelentia Supplies, Global Office Solutions และ CGV Supplier
#
# 1. **Excelentia Supplies** - มีราคา Unit Price ต่ำสุดอยู่ที่ 61.5 ดอลลาร์ มีอัตราการจัดส่งตรงเวลา 95% และอัตราการคืนสินค้า 2% ซึ่งเป็นตัวเลือกที่ดีที่สุด
# 2. **Global Office Solutions** - มีราคา Unit Price อยู่ที่ 76.9 ดอลลาร์ มีอัตราการจัดส่งตรงเวลา 92% และอัตราการคืนสินค้า 1% เป็นตัวเลือกที่สอง
# 3. **CGV Supplier** - มีราคา Unit Price สูงสุดอยู่ที่ 92.3 ดอลลาร์ ไม่มีข้อมูลเกี่ยวกับอัตราการจัดส่งตรงเวลาและอัตราการคืนสินค้า จึงเป็นตัวเลือกที่แย่ที่สุด
#
# โดยรวมแล้ว Excelentia Supplies เป็นตัวเลือกที่ดีที่สุดสำหรับการจัดซื้อจัดจ้าง เนื่องจากราคาถูกที่สุดและมีอัตราการจัดส่งตรงเวลาที่ดี และมีอัตราการคืนสินค้าที่ไม่สูงเกินไป ในขณะที่ CGV Supplier เป็นตัวเลือกที่แย่ที่สุดเนื่องจากราคาสูงสุดและไม่มีข้อมูลเกี่ยวกับอัตราการจัดส่งตรงเวลาและอัตราการคืนสินค้า

# %%
import requests
import json

# Base URL of your FastAPI server
# url = "http://127.0.0.1:8080/chat/completions"
url = "https://agentlab-th.1u1bpgsnsvuw.us-south.codeengine.appdomain.cloud/chat/completions"

# Sample user message
# user_query = "ช่วยค้นคว้าเกี่ยวกับผู้จัดจำหน่าย Xtralife ให้คะแนนซัพพลายเออร์จากบนลงล่างโดยพิจารณาจากตัวเลือกที่ดีที่สุดไปจนถึงแย่ที่สุด พร้อมทั้งแบ่งปันเหตุผลด้วย ข้อมูลราคาสำหรับซัพพลายเออร์ ทั้งหมด 3 เจ้า มีดังนี้: [{'Unit Price': 61.5, 'Pricebook Name': 'Excelentia Supplies'}, {'Unit Price': 76.9, 'Pricebook Name': 'Global Office Solutions'}, {'Unit Price': 92.3, 'Pricebook Name': 'CGV Supplier'}] พิจารณาข้อกำหนดและบทวิจารณ์การขายของซัพพลายเออร์เหล่านี้ด้วย"
user_query = "ผู้จัดจำหน่ายรายใดระหว่าง Excelentia Supplies และ Global Office Supplies เป็นตัวเลือกที่เหมาะสมในการซื้อผลิตภัณฑ์ Xtralife ช่วยให้รายการข้อดีและข้อเสียของผู้จัดจำหน่ายแต่ละราย"

# Payload for the POST request
payload = {
    "messages": [
        {"role": "user", "content": user_query}
    ],
    "stream": False,
    "extra_body": {
        "thread_id": "thread-123"
    }
}

# Headers including Authorization and optional thread ID
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer API_KEY",  # Replace with actual token if needed
    "X-IBM-THREAD-ID": "thread-123"
}

# Send POST request
response = requests.post(url, headers=headers, data=json.dumps(payload))

# Check response status and print result
if response.status_code == 200:
    print("✅ Success")
    print("Response:")
    print(response.json())
else:
    print("❌ Failed with status code:", response.status_code)
    print("Response:", response.text)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# ✅ Success
# Response:
# {'id': 'b0191943-e7cd-4377-823b-a4331305b77c', 'object': 'chat.completion', 'created': 1744335791, 'model': 'wx.ai AI service', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'ผู้จัดจำหน่ายที่เหมาะสมในการซื้อผลิตภัณฑ์ Xtralife คือ Excelentia Supplies และ Global Office Supplies ทั้งสองมีข้อดีและข้อเสียที่แตกต่างกัน Excelentia Supplies มียอดขายแข็งแกร่งและมีอัตราการจัดส่งตรงเวลาที่ดี แต่อัตราการคืนสินค้าสูงเล็กน้อย ในขณะที่ Global Office Supplies มีผลการขายคงที่ แต่อัตราการจัดส่งตรงเวลายังต่ำกว่า ควรพิจารณาทบทวนกระบวนการควบคุมคุณภาพและติดตามการปรับปรุงการจัดส่งเพิ่มเติม\n\nข้อดีของ Excelentia Supplies:\n- ยอดขายแข็งแกร่ง\n- อัตราการจัดส่งตรงเวลาที่ดี\nข้อเสียของ Excelentia Supplies:\n- อัตราการคืนสินค้าสูงเล็กน้อย\n\nข้อดีของ Global Office Supplies:\n- ผลการขายคงที่\n- อัตราการคืนสินค้าต่ำ\nข้อเสียของ Global Office Supplies:\n- อัตราการจัดส่งตรงเวลายังต่ำกว่า\n\nควรพิจารณากระบวนการคืนสินค้าและความถี่ในการสั่งซื้อเพื่อหลีกเลี่ยงปัญหาการขาดสินค้า และควรติดตามผลการดำเนินงานของผู้จัดจำหน่ายทั้งสองเพื่อประเมินประสิทธิภาพการจัดส่ง, อัตราการคืนสินค้า, และความพึงพอใจของลูกค้า'}, 'finish_reason': 'stop'}]}
# ผู้จัดจำหน่ายที่เหมาะสมในการซื้อผลิตภัณฑ์ Xtralife คือ Excelentia Supplies และ Global Office Supplies ทั้งสองมีข้อดีและข้อเสียที่แตกต่างกัน Excelentia Supplies มียอดขายแข็งแกร่งและมีอัตราการจัดส่งตรงเวลาที่ดี แต่อัตราการคืนสินค้าสูงเล็กน้อย ในขณะที่ Global Office Supplies มีผลการขายคงที่ แต่อัตราการจัดส่งตรงเวลายังต่ำกว่า ควรพิจารณาทบทวนกระบวนการควบคุมคุณภาพและติดตามการปรับปรุงการจัดส่งเพิ่มเติม
#
# ข้อดีของ Excelentia Supplies:
# - ยอดขายแข็งแกร่ง
# - อัตราการจัดส่งตรงเวลาที่ดี
# ข้อเสียของ Excelentia Supplies:
# - อัตราการคืนสินค้าสูงเล็กน้อย
#
# ข้อดีของ Global Office Supplies:
# - ผลการขายคงที่
# - อัตราการคืนสินค้าต่ำ
# ข้อเสียของ Global Office Supplies:
# - อัตราการจัดส่งตรงเวลายังต่ำกว่า
#
# ควรพิจารณากระบวนการคืนสินค้าและความถี่ในการสั่งซื้อเพื่อหลีกเลี่ยงปัญหาการขาดสินค้า และควรติดตามผลการดำเนินงานของผู้จัดจำหน่ายทั้งสองเพื่อประเมินประสิทธิภาพการจัดส่ง, อัตราการคืนสินค้า, และความพึงพอใจของลูกค้า

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'ผู้จัดจำหน่ายที่เหมาะสมในการซื้อผลิตภัณฑ์ Xtralife คือ Excelentia Supplies และ Global Office Supplies ทั้งสองมีข้อดีและข้อเสียที่แตกต่างกัน Excelentia Supplies มียอดขายแข็งแกร่งและมีอัตราการจัดส่งตรงเวลาที่ดี แต่อัตราการคืนสินค้าสูงเล็กน้อย ในขณะที่ Global Office Supplies มีผลการขายคงที่ แต่อัตราการจัดส่งตรงเวลายังต่ำกว่า ควรพิจารณาทบทวนกระบวนการควบคุมคุณภาพและติดตามการปรับปรุงการจัดส่งเพิ่มเติมสำหรับทั้งสองผู้จัดจำหน่าย'
